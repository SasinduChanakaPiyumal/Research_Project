# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = "Z:\\Sasindu\\2_Discharge_ET_Madagascar\\2_Discharge_ET_Madagascar\\2a_Monthly_mean_discharge_m3_s_KW_Madagascar.xlsx"
data = pd.read_excel(path)
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#     seg_id    2000_01    2000_02    2000_03       2000_04       2000_05  \
# 0  2000007   9.247824  37.588341  39.892441  2.548718e-01  5.616210e-03
# 1  2000116  21.988350   9.098341   8.919436  2.519191e-07  2.519191e-07
# 2  2000180   4.313504   0.683950   0.001035  3.551793e-05  2.531244e-07
# 3  2000292   5.762424  13.937943   5.447133  2.528637e-07  2.528637e-07
# 4  2000340  13.518731   3.732042   0.325755  2.528902e-07  2.528902e-07
#
#         2000_06       2000_07       2000_08       2000_09  ...       2020_05  \
# 0  1.830893e+00  6.671751e+00  2.735410e-02  5.135357e-03  ...  1.426127e+00
# 1  2.519191e-07  2.519191e-07  2.519191e-07  2.519191e-07  ...  2.519191e-07
# 2  2.531244e-07  2.531244e-07  2.531244e-07  2.531244e-07  ...  2.531244e-07
# 3  2.528637e-07  2.528637e-07  2.528637e-07  2.528637e-07  ...  2.528637e-07
# 4  2.528902e-07  2.528902e-07  2.528902e-07  2.528902e-07  ...  2.528902e-07
#
#         2020_06       2020_07       2020_08       2020_09       2020_10  \
# 0  2.899988e+01  2.428523e+01  4.114094e+00  2.509294e-07  2.509294e-07
# 1  2.519191e-07  2.519191e-07  2.519191e-07  2.519191e-07  2.519191e-07
# 2  2.531244e-07  2.531244e-07  2.531244e-07  2.531244e-07  2.531244e-07
# 3  2.528637e-07  2.528637e-07  2.528637e-07  2.528637e-07  1.971186e+00
# 4  2.528902e-07  2.528902e-07  2.528902e-07  2.528902e-07  2.528902e-07
#
#         2020_11       2020_12    2021_01    2021_02
# 0  2.509294e-07  6.755863e-01   0.135837  22.304459
# 1  2.519191e-07  8.091949e-01  14.402277  25.172817
# 2  2.531244e-07  2.531244e-07   0.013712   0.890362
# 3  2.352719e-02  1.014805e+01  20.132355  20.596531
# 4  2.528902e-07  2.528902e-07   0.049165  17.524691
#
# [5 rows x 255 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1202 entries, 0 to 1201
# Columns: 255 entries, seg_id to 2021_02
# dtypes: float64(254), int64(1)
# memory usage: 2.3 MB

# %%
str(df['seg_id'])
# Out:
# '0       2000007\n1       2000116\n2       2000180\n3       2000292\n4       2000340\n         ...   \n1197    2060533\n1198    2060578\n1199    2060595\n1200    2060600\n1201    2060638\nName: seg_id, Length: 1202, dtype: int64'

# %%
transposed_df = df.T

# %%
transposed_df.head()
# Out:
#                  0             1             2             3             4     \
# seg_id   2.000007e+06  2.000116e+06  2.000180e+06  2.000292e+06  2.000340e+06
# 2000_01  9.247824e+00  2.198835e+01  4.313504e+00  5.762424e+00  1.351873e+01
# 2000_02  3.758834e+01  9.098341e+00  6.839498e-01  1.393794e+01  3.732042e+00
# 2000_03  3.989244e+01  8.919436e+00  1.034757e-03  5.447133e+00  3.257551e-01
# seg_id     2060533.0    2060578.0    2060595.0    2060600.0    2060638.0
# 2000_01  2092.356689  2142.922852  3840.596191  2143.549316  3769.394043
# 2000_02  1038.004761  1056.252686  4145.958008  1072.461670  4326.594727
# 2000_03   939.669617   946.485596  1884.377563   960.142029  2080.091553
# 2000_04    57.926319    59.185631    18.465107    61.664268    37.893867
# 2000_05     4.742089     5.040978     2.203797     5.721770     6.230992
#
# [5 rows x 1202 columns]

# %%
transposed_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 254 entries, 2000_01 to 2021_02
# Columns: 1202 entries, 2000007.0 to 2060638.0
# dtypes: float64(1202)
# memory usage: 2.3+ MB

# %%
transposed_df.index = pd.to_datetime(transposed_df.index, format='%Y_%m')

# Rename the index to 'Date'
transposed_df.reset_index(inplace=True)
transposed_df.rename(columns={'index': 'Date'}, inplace=True)

# %%
transposed_df.head()
# Out:
# seg_id       Date  2000007.0     2000116.0     2000180.0     2000292.0  \
# 0      2000-01-01   9.247824  2.198835e+01  4.313504e+00  5.762424e+00
# 1      2000-02-01  37.588341  9.098341e+00  6.839498e-01  1.393794e+01
# 2      2000-03-01  39.892441  8.919436e+00  1.034757e-03  5.447133e+00
# 3      2000-04-01   0.254872  2.519191e-07  3.551793e-05  2.528637e-07
# 4      2000-05-01   0.005616  2.519191e-07  2.531244e-07  2.528637e-07
#
# seg_id     2000340.0     2000351.0     2000385.0     2000392.0     2000432.0  \
# 0       1.351873e+01  1.323398e+00  2.877800e+01  1.025476e+01  1.938319e+00
# 1       3.732042e+00  1.043497e+01  3.090279e+01  1.418348e+00  6.573535e+00
# 2       3.257551e-01  1.063047e+01  7.159194e+00  1.210476e-03  8.071157e+00
# 3       2.528902e-07  4.852504e+00  2.875650e-03  2.532876e-07  6.272197e-01
# 4       2.528902e-07  2.535500e-07  2.538360e-07  2.532876e-07  2.536018e-07
#
# seg_id  ...    2060227.0    2060279.0    2060377.0    2060427.0    2060521.0  \
# 0       ...  3758.115234  3797.839111  1950.355835  2011.077148  3734.057129
# 1       ...  2210.497070  2250.117920   972.477905   989.631409  3981.237305
# 2       ...  2221.910645  2287.498291   908.833618   911.530945  1796.627686
# 3       ...    56.553185    64.956734    51.386272    51.996117     9.886827
# 4       ...     2.356567     3.366750     3.339295     3.432722     1.428212
#
# seg_id    2060533.0    2060578.0    2060595.0    2060600.0    2060638.0
# 0       2092.356689  2142.922852  3840.596191  2143.549316  3769.394043
# 1       1038.004761  1056.252686  4145.958008  1072.461670  4326.594727
# 2        939.669617   946.485596  1884.377563   960.142029  2080.091553
# 3         57.926319    59.185631    18.465107    61.664268    37.893867
# 4          4.742089     5.040978     2.203797     5.721770     6.230992
#
# [5 rows x 1203 columns]

# %%
# Convert column names to strings and remove characters after the '.' and the '.' itself
transposed_df.columns = [str(col).split('.')[0] for col in transposed_df.columns]

# %%
transposed_df.head()
# Out:
#         Date    2000007       2000116       2000180       2000292  \
# 0 2000-01-01   9.247824  2.198835e+01  4.313504e+00  5.762424e+00
# 1 2000-02-01  37.588341  9.098341e+00  6.839498e-01  1.393794e+01
# 2 2000-03-01  39.892441  8.919436e+00  1.034757e-03  5.447133e+00
# 3 2000-04-01   0.254872  2.519191e-07  3.551793e-05  2.528637e-07
# 4 2000-05-01   0.005616  2.519191e-07  2.531244e-07  2.528637e-07
#
#         2000340       2000351       2000385       2000392       2000432  ...  \
# 0  1.351873e+01  1.323398e+00  2.877800e+01  1.025476e+01  1.938319e+00  ...
# 1  3.732042e+00  1.043497e+01  3.090279e+01  1.418348e+00  6.573535e+00  ...
# 2  3.257551e-01  1.063047e+01  7.159194e+00  1.210476e-03  8.071157e+00  ...
# 3  2.528902e-07  4.852504e+00  2.875650e-03  2.532876e-07  6.272197e-01  ...
# 4  2.528902e-07  2.535500e-07  2.538360e-07  2.532876e-07  2.536018e-07  ...
#
#        2060227      2060279      2060377      2060427      2060521  \
# 0  3758.115234  3797.839111  1950.355835  2011.077148  3734.057129
# 1  2210.497070  2250.117920   972.477905   989.631409  3981.237305
# 2  2221.910645  2287.498291   908.833618   911.530945  1796.627686
# 3    56.553185    64.956734    51.386272    51.996117     9.886827
# 4     2.356567     3.366750     3.339295     3.432722     1.428212
#
#        2060533      2060578      2060595      2060600      2060638
# 0  2092.356689  2142.922852  3840.596191  2143.549316  3769.394043
# 1  1038.004761  1056.252686  4145.958008  1072.461670  4326.594727
# 2   939.669617   946.485596  1884.377563   960.142029  2080.091553
# 3    57.926319    59.185631    18.465107    61.664268    37.893867
# 4     4.742089     5.040978     2.203797     5.721770     6.230992
#
# [5 rows x 1203 columns]

# %%
transposed_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 0 to 253
# Columns: 1203 entries, Date to 2060638
# dtypes: datetime64[ns](1), float64(1202)
# memory usage: 2.3 MB

# %%
transposed_df.columns
# Out:
# Index(['Date', '2000007', '2000116', '2000180', '2000292', '2000340',
#        '2000351', '2000385', '2000392', '2000432',
#        ...
#        '2060227', '2060279', '2060377', '2060427', '2060521', '2060533',
#        '2060578', '2060595', '2060600', '2060638'],
#       dtype='object', length=1203)

# %%
for col in transposed_df.columns:
    if transposed_df[col].isnull().sum() >0:
        print(col ,"-->",transposed_df[col].isnull().sum())
print("No missing values detected")
# Out:
# No missing values detected

# %%
import plotnine as p9 
from plotnine import *

# %%
(ggplot(transposed_df, aes(x='Date', y='2000007')) + geom_line() + labs(x='date', y='River Discharge'))

# %%
(ggplot(transposed_df, aes(x='Date', y='2000116')) + geom_line() + labs(x='date', y='River Discharge'))

# %%
(ggplot(transposed_df, aes(x='Date', y='2000180')) + geom_line() + labs(x='date', y='River Discharge'))

# %%
transposed_df['year'] = transposed_df['Date'].dt.year
transposed_df['month'] = transposed_df['Date'].dt.month

# %%
ggplot(transposed_df, aes(x='month', y='2000007', color='year'))+geom_point()

# %%
ggplot(transposed_df, aes(x='month', y='2000007',group='year' ,color='year'))+geom_point()+geom_line()+scale_x_continuous(breaks=range(1, 13))

# %%
ggplot(transposed_df, aes(x='month', y='2000007', group='month', color='month')) + geom_boxplot() + scale_x_continuous(breaks=range(1, 13))

# %%
ggplot(transposed_df, aes(x='year', y='2000007', group='year', color='year')) + geom_boxplot()

# %%
missing_summary = transposed_df.isnull().sum()
print(missing_summary.sort_values(ascending=False).head(10))  # top 10 with most missing

# Percentage of missing values
missing_percentage = transposed_df.isnull().mean() * 100
# Out:
# month      0
# Date       0
# 2000007    0
# 2000116    0
# 2000180    0
# 2060029    0
# 2060014    0
# 2059974    0
# 2059948    0
# 2059912    0
# dtype: int64

# %%
duplicates = transposed_df[transposed_df.duplicated()]

# Count duplicated rows
print(f"Number of fully duplicated rows: {duplicates.shape[0]}")

# Display them
print(duplicates.head())
# Out:
# Number of fully duplicated rows: 0
# Empty DataFrame
# Columns: [Date, 2000007, 2000116, 2000180, 2000292, 2000340, 2000351, 2000385, 2000392, 2000432, 2000495, 2000613, 2000689, 2000821, 2000826, 2000892, 2000907, 2000944, 2000954, 2001015, 2001068, 2001114, 2001208, 2001210, 2001267, 2001287, 2001313, 2001359, 2001363, 2001401, 2001427, 2001460, 2001488, 2001502, 2001508, 2001531, 2001545, 2001546, 2001594, 2001648, 2001669, 2001692, 2001712, 2001808, 2001905, 2001910, 2001921, 2001931, 2002019, 2002066, 2002141, 2002148, 2002168, 2002188, 2002262, 2002291, 2002333, 2002364, 2002389, 2002395, 2002407, 2002509, 2002654, 2002679, 2002682, 2002696, 2002728, 2002750, 2002798, 2002832, 2002856, 2002858, 2002965, 2003086, 2003144, 2003154, 2003247, 2003256, 2003282, 2003312, 2003322, 2003365, 2003437, 2003471, 2003515, 2003535, 2003555, 2003604, 2003617, 2003620, 2003665, 2003681, 2003696, 2003701, 2003805, 2003962, 2003967, 2004085, 2004164, 2004238, ...]
# Index: []
#
# [0 rows x 1205 columns]

# %%
from scipy.stats import zscore

# Keep only numeric columns
numeric_df = transposed_df.select_dtypes(include=['number'])

# Now apply z-score safely
z_scores = numeric_df.apply(zscore)

# Identify anomalies
anomalies = (z_scores.abs() > 3)

# %%
anomaly_counts = anomalies.sum()
print(anomaly_counts.sort_values(ascending=False).head())
# Out:
# 2024165    11
# 2011368    11
# 2028704    11
# 2029429    11
# 2036649    11
# dtype: int64

# %%
transposed_df.iloc[:, 1:10].plot(subplots=True, figsize=(12, 10), title='Sample Time Series')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(transposed_df.corr().iloc[:30, :30], cmap='coolwarm')  # slice to avoid memory issue
plt.title("Correlation (first 30 columns)")
plt.show()

# %%
corr_matrix = transposed_df.corr(numeric_only=True)

# %%
mask = np.triu(np.ones(corr_matrix.shape), k=1).astype(bool)
upper_tri = corr_matrix.where(mask)

# Convert to long format, drop NaNs
corr_pairs = upper_tri.stack().reset_index()
corr_pairs.columns = ['Variable 1', 'Variable 2', 'Correlation']

# Sort by absolute correlation
top_corr_pairs = corr_pairs.reindex(corr_pairs['Correlation'].abs().sort_values(ascending=False).index)

# Show top 20 pairs
print(top_corr_pairs.head(50))
# Out:
#        Variable 1 Variable 2  Correlation
# 723953    2059857    2059881     0.999998
# 723171    2057891    2057948     0.999989
# 723855    2059485    2059549     0.999988
# 724116    2060188    2060227     0.999980
# 723345    2058137    2058193     0.999978
# 724036    2059974    2060029     0.999976
# 722191    2056633    2056728     0.999975
# 722829    2057209    2057320     0.999972
# 715826    2053148    2053417     0.999972
# 720637    2055265    2055394     0.999968
# 723741    2059032    2059076     0.999965
# 724101    2060117    2060188     0.999965
# 724185    2060533    2060578     0.999959
# 695773    2048136    2048653     0.999958
# 723540    2058586    2058627     0.999958
# 724017    2059948    2060014     0.999954
# 724161    2060377    2060427     0.999954
# 723303    2058065    2058137     0.999952
# 713625    2052560    2052829     0.999952
# 722555    2056979    2057075     0.999949
# 723996    2059912    2059948     0.999945
# 721651    2055912    2056073     0.999945
# 682896    2045783    2046596     0.999942
# 717186    2053545    2053777     0.999942
# 710351    2051384    2051676     0.999940
# 724070    2060029    2060098     0.999939
# 713922    2052781    2053120     0.999935
# 723576    2058627    2058703     0.999931
# 717544    2053843    2054088     0.999931
# 700135    2049108    2049737     0.999931
# 691067    2047003    2047892     0.999927
# 723079    2057729    2057891     0.999926
# 724192    2060578    2060600     0.999925
# 720555    2055232    2055448     0.999919
# 716710    2053422    2053858     0.999918
# 713781    2052770    2053191     0.999917
# 722667    2057074    2057199     0.999914
# 723612    2058703    2058788     0.999912
# 718218    2054033    2054377     0.999905
# 721433    2055674    2055912     0.999904
# 722439    2056859    2057074     0.999900
# 724103    2060117    2060227     0.999894
# 680269    2045371    2046248     0.999890
# 698351    2048820    2049662     0.999884
# 721792    2056073    2056258     0.999883
# 708817    2051059    2051573     0.999882
# 701433    2049245    2049982     0.999881
# 720383    2055186    2055424     0.999880
# 712278    2051845    2052467     0.999874
# 715959    2053191    2053545     0.999871

# %%
print(top_corr_pairs[top_corr_pairs['Correlation']>0.8])
# Out:
#        Variable 1 Variable 2  Correlation
# 723953    2059857    2059881     0.999998
# 723171    2057891    2057948     0.999989
# 723855    2059485    2059549     0.999988
# 724116    2060188    2060227     0.999980
# 723345    2058137    2058193     0.999978
# ...           ...        ...          ...
# 281791    2012447    2052770     0.800005
# 660526    2042418    2053036     0.800002
# 533886    2029031    2045917     0.800000
# 611193    2036483    2038284     0.800000
# 265576    2011641    2048822     0.800000
#
# [264724 rows x 3 columns]

# %%
transposed_df.shape
# Out:
# (254, 1205)

# %%
transposed_df.describe()
# Out:
#                                 Date       2000007       2000116  \
# count                            254  2.540000e+02  2.540000e+02
# mean   2010-07-17 01:02:21.732283392  1.105339e+01  4.914106e+00
# min              2000-01-01 00:00:00  2.509294e-07  2.519191e-07
# 25%              2005-04-08 12:00:00  1.983913e-01  2.519191e-07
# 50%              2010-07-16 12:00:00  4.734820e+00  2.519191e-07
# 75%              2015-10-24 06:00:00  1.884384e+01  7.190742e+00
# max              2021-02-01 00:00:00  7.892738e+01  4.795175e+01
# std                              NaN  1.370419e+01  8.675747e+00
#
#             2000180       2000292       2000340       2000351       2000385  \
# count  2.540000e+02  2.540000e+02  2.540000e+02  2.540000e+02  2.540000e+02
# mean   7.616887e-01  5.409517e+00  9.519139e-01  6.045631e+00  7.801830e+00
# min    2.531244e-07  2.528637e-07  2.528902e-07  2.535500e-07  2.538360e-07
# 25%    2.531244e-07  2.528637e-07  2.528902e-07  2.535500e-07  2.538360e-07
# 50%    2.531244e-07  2.528637e-07  2.528902e-07  2.433445e-03  1.372792e-04
# 75%    3.708033e-01  9.027223e+00  2.242608e-02  1.058160e+01  1.268177e+01
# max    1.598348e+01  4.592833e+01  1.821838e+01  4.950505e+01  5.595928e+01
# std    1.887719e+00  8.905380e+00  3.058280e+00  9.814738e+00  1.275436e+01
#
#             2000392       2000432  ...      2060377      2060427      2060521  \
# count  2.540000e+02  2.540000e+02  ...   254.000000   254.000000   254.000000
# mean   8.158020e-01  4.636419e+00  ...   459.788474   463.864240  1321.783544
# min    2.532876e-07  2.536018e-07  ...     0.102478     0.107254     0.056763
# 25%    2.532876e-07  2.536018e-07  ...     0.974275     0.979193     0.339298
# 50%    2.532876e-07  2.536018e-07  ...    12.769839    13.008353    10.903313
# 75%    1.237457e-01  7.417434e+00  ...   705.039368   705.838104  2118.169312
# max    1.576067e+01  3.913057e+01  ...  3923.368896  3973.661865  9441.986328
# std    2.233585e+00  7.916952e+00  ...   776.233071   785.682834  2088.894604
#
#            2060533      2060578      2060595      2060600      2060638  \
# count   254.000000   254.000000   254.000000   254.000000   254.000000
# mean    470.679037   473.588064  1361.599791   474.885758  1400.423017
# min       0.138998     0.145892     0.083758     0.161934     0.222375
# 25%       1.146912     1.184029     0.469276     1.191538     1.025830
# 50%      14.978655    15.593595    12.741937    16.588580    26.643433
# 75%     716.666016   717.640350  2043.851379   723.079941  2109.839417
# max    3992.138184  4016.657227  9753.083008  3999.617920  9952.483398
# std     798.367935   804.874768  2155.574631   806.305754  2212.770475
#
#               year       month
# count   254.000000  254.000000
# mean   2010.086614    6.460630
# min    2000.000000    1.000000
# 25%    2005.000000    3.000000
# 50%    2010.000000    6.000000
# 75%    2015.000000    9.000000
# max    2021.000000   12.000000
# std       6.121334    3.473847
#
# [8 rows x 1205 columns]

# %%
segments_to_plot = transposed_df.columns[1:5]  # pick 3 segments
transposed_df[segments_to_plot].plot(figsize=(14, 5), title="Discharge Time Series")
plt.ylabel("Discharge")
plt.grid()
plt.show()

# %%
## Rolling average for one segment
segment = transposed_df.columns[1]
transposed_df[[segment]].plot(title=f"{segment} - Daily Discharge", figsize=(14,4))
transposed_df[segment].rolling(window=30).mean().plot(label='30-day rolling mean')
plt.legend()
plt.grid()
plt.show()
